# %%
import gymnasium as gym
import ale_py
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3 import PPO
import os

# 生成向量化环境
env = make_vec_env(
    "ALE/Alien-v5",
    n_envs=4,
    wrapper_class=AtariWrapper,
    vec_env_cls=None  # 默认 DummyVecEnv
)

env.envs[0].spec
# Out:
# EnvSpec(id='ALE/Alien-v5', entry_point='ale_py.env:AtariEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, disable_env_checker=False, kwargs={'game': 'alien', 'repeat_action_probability': 0.25, 'full_action_space': False, 'frameskip': 4, 'max_num_frames_per_episode': 108000, 'render_mode': 'rgb_array'}, namespace='ALE', name='Alien', version=5, additional_wrappers=(WrapperSpec(name='Monitor', entry_point='stable_baselines3.common.monitor:Monitor', kwargs=None), WrapperSpec(name='NoopResetEnv', entry_point='stable_baselines3.common.atari_wrappers:NoopResetEnv', kwargs=None), WrapperSpec(name='MaxAndSkipEnv', entry_point='stable_baselines3.common.atari_wrappers:MaxAndSkipEnv', kwargs=None), WrapperSpec(name='EpisodicLifeEnv', entry_point='stable_baselines3.common.atari_wrappers:EpisodicLifeEnv', kwargs=None), WrapperSpec(name='FireResetEnv', entry_point='stable_baselines3.common.atari_wrappers:FireResetEnv', kwargs=None), WrapperSpec(name='WarpFrame', entry_point='stable_baselines3.common.atari_wrappers:WarpFrame', kwargs=None), WrapperSpec(name='ClipRewardEnv', entry_point='stable_baselines3.common.atari_wrappers:ClipRewardEnv', kwargs=None), WrapperSpec(name='AtariWrapper', entry_point='stable_baselines3.common.atari_wrappers:AtariWrapper', kwargs=None)), vector_entry_point='ale_py.vector_env:AtariVectorEnv')

# %%
model = PPO(
    'CnnPolicy',
    env,
    verbose=1,
    tensorboard_log = os.path.join('./runs/ppo/ppo_alien', 'tensorboard'),
    n_steps=128,
    batch_size = 256,
    n_epochs = 4,
    learning_rate = 2e-4,
    gamma = 0.99,
    clip_range = 0.1,
    ent_coef = 0.01, 
)

model.learn(total_timesteps = 10_000)

model.save(r"./runs/ppo/ppo_alien-v5")
del model

# 加载模型
model = PPO.load("./runs/ppo/ppo_alien-v5", env=env)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./runs/ppo/ppo_alien\tensorboard\PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 516      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    fps             | 338      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 512      |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 587          |
# |    ep_rew_mean          | 339          |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0029980475 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -0.00375     |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.51         |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 6.23         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 602         |
# |    ep_rew_mean          | 342         |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.002610656 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | -0.00715    |
# |    learning_rate        | 0.0002      |
# |    loss                 | 2.77        |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 5.61        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 593          |
# |    ep_rew_mean          | 328          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0021007354 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.0015       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.78         |
# |    n_updates            | 12           |
# |    policy_gradient_loss | 0.000685     |
# |    value_loss           | 7.19         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 605         |
# |    ep_rew_mean          | 337         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.005016578 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.000946    |
# |    learning_rate        | 0.0002      |
# |    loss                 | 3.52        |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00448    |
# |    value_loss           | 7.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 613         |
# |    ep_rew_mean          | 337         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.004003231 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.000301    |
# |    learning_rate        | 0.0002      |
# |    loss                 | 4.78        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00346    |
# |    value_loss           | 10.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 624          |
# |    ep_rew_mean          | 372          |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0027731073 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0147       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.66         |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 7.76         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 618          |
# |    ep_rew_mean          | 358          |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 8            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0013281015 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0185       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.76         |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 7.56         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 627          |
# |    ep_rew_mean          | 363          |
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 9            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0009040185 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0302       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.68         |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00272     |
# |    value_loss           | 6.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 633          |
# |    ep_rew_mean          | 357          |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 10           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0010034508 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0428       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.01         |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 6.59         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 631          |
# |    ep_rew_mean          | 349          |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 11           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0027900771 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.067        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.55         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 5.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 649          |
# |    ep_rew_mean          | 347          |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 12           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0023496726 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0875       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.34         |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 5.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 650          |
# |    ep_rew_mean          | 345          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 13           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0008492186 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.44         |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.000984    |
# |    value_loss           | 4.87         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 654          |
# |    ep_rew_mean          | 350          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 14           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0008066156 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.34         |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 7.08         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 659          |
# |    ep_rew_mean          | 350          |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 15           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0012179171 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0931       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.68         |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 7.78         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 654          |
# |    ep_rew_mean          | 348          |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 16           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0022525382 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0442       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 4.19         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 8.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 654          |
# |    ep_rew_mean          | 353          |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 17           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0017622809 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 4.31         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 8.49         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 648          |
# |    ep_rew_mean          | 345          |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 18           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0005338555 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.55         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -8.57e-06    |
# |    value_loss           | 5.23         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 640           |
# |    ep_rew_mean          | 343           |
# | time/                   |               |
# |    fps                  | 314           |
# |    iterations           | 19            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 0.00085495424 |
# |    clip_fraction        | 0.00586       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.172         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.51          |
# |    n_updates            | 72            |
# |    policy_gradient_loss | -0.00128      |
# |    value_loss           | 7.45          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 637          |
# |    ep_rew_mean          | 340          |
# | time/                   |              |
# |    fps                  | 312          |
# |    iterations           | 20           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0008030004 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.38         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 7.76         |
# ------------------------------------------
# Wrapping the env in a VecTransposeImage.

# %%
# !jupyter nbconvert --to script atari_ppo.ipynb
# Out:
# [NbConvertApp] Converting notebook atari_ppo.ipynb to script
# [NbConvertApp] Writing 867 bytes to atari_ppo.py
